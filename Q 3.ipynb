# %%
import cv2
from matplotlib import pyplot as plt
car_image = cv2.imread('car.jpg')

H, W, C = car_image.shape
car_image_90= cv2.rotate(car_image, cv2.ROTATE_90_CLOCKWISE)
Matrix = cv2.getRotationMatrix2D((h/2,w/2),-45,1) 
car_image_45 = cv2.warpAffine(car_image,Matrix,(H,W))

plt.subplot(121),plt.imshow(car_image_90),plt.title('Image Rotated 90')
plt.subplot(122),plt.imshow(car_image_45),plt.title('Image Rotated 45')

cv2.imwrite('Q3_Image Rotated 90.jpg', car_image_90)
cv2.imwrite('Q3_Image Rotated 45.jpg',car_image_45)
# Out:
# True
